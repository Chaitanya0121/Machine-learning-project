# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import regex as re

# %% [markdown]
# ## Reading the data

# %%
data = pd.read_csv("Car details v3.csv")
data.head()
# Out:
#                            name  year  km_driven    fuel seller_type  \
# 0        Maruti Swift Dzire VDI  2014     145500  Diesel  Individual
# 1  Skoda Rapid 1.5 TDI Ambition  2014     120000  Diesel  Individual
# 2      Honda City 2017-2020 EXi  2006     140000  Petrol  Individual
# 3     Hyundai i20 Sportz Diesel  2010     127000  Diesel  Individual
# 4        Maruti Swift VXI BSIII  2007     120000  Petrol  Individual
#
#   transmission         owner mileage (kmpl)  engine (cc)   max_power  \
# 0       Manual   First Owner           23.4       1248.0      74 bhp
# 1       Manual  Second Owner          21.14       1498.0  103.52 bhp
# 2       Manual   Third Owner           17.7       1497.0      78 bhp
# 3       Manual   First Owner             23       1396.0      90 bhp
# 4       Manual   First Owner           16.1       1298.0    88.2 bhp
#
#                      torque  seats  selling_price
# 0            190Nm@ 2000rpm    5.0         450000
# 1       250Nm@ 1500-2500rpm    5.0         370000
# 2     12.7@ 2,700(kgm@ rpm)    5.0         158000
# 3  22.4 kgm at 1750-2750rpm    5.0         225000
# 4     11.5@ 4,500(kgm@ rpm)    5.0         130000

# %%
data.describe(include = 'all')
# Out:
#                           name         year     km_driven    fuel seller_type  \
# count                     8128  8128.000000  8.128000e+03    8128        8128
# unique                    2058          NaN           NaN       4           3
# top     Maruti Swift Dzire VDI          NaN           NaN  Diesel  Individual
# freq                       129          NaN           NaN    4402        6766
# mean                       NaN  2013.804011  6.981951e+04     NaN         NaN
# std                        NaN     4.044249  5.655055e+04     NaN         NaN
# min                        NaN  1983.000000  1.000000e+00     NaN         NaN
# 25%                        NaN  2011.000000  3.500000e+04     NaN         NaN
# 50%                        NaN  2015.000000  6.000000e+04     NaN         NaN
# 75%                        NaN  2017.000000  9.800000e+04     NaN         NaN
# max                        NaN  2020.000000  2.360457e+06     NaN         NaN
#
#        transmission        owner mileage (kmpl)  engine (cc) max_power  \
# count          8128         8128           7907  7907.000000      7913
# unique            2            5            381          NaN       322
# top          Manual  First Owner           18.9          NaN    74 bhp
# freq           7078         5289            225          NaN       377
# mean            NaN          NaN            NaN  1458.625016       NaN
# std             NaN          NaN            NaN   503.916303       NaN
# min             NaN          NaN            NaN   624.000000       NaN
# 25%             NaN          NaN            NaN  1197.000000       NaN
# 50%             NaN          NaN            NaN  1248.000000       NaN
# 75%             NaN          NaN            NaN  1582.000000       NaN
# max             NaN          NaN            NaN  3604.000000       NaN
#
#                 torque        seats  selling_price
# count             7906  7907.000000   8.128000e+03
# unique             441          NaN            NaN
# top     190Nm@ 2000rpm          NaN            NaN
# freq               530          NaN            NaN
# mean               NaN     5.416719   6.382718e+05
# std                NaN     0.959588   8.062534e+05
# min                NaN     2.000000   2.999900e+04
# 25%                NaN     5.000000   2.549990e+05
# 50%                NaN     5.000000   4.500000e+05
# 75%                NaN     5.000000   6.750000e+05
# max                NaN    14.000000   1.000000e+07

# %%
data = data.dropna() 
data = data.drop(['name','torque'], axis = 1)
data.head()
# Out:
#    year  km_driven    fuel seller_type transmission         owner  \
# 0  2014     145500  Diesel  Individual       Manual   First Owner
# 1  2014     120000  Diesel  Individual       Manual  Second Owner
# 2  2006     140000  Petrol  Individual       Manual   Third Owner
# 3  2010     127000  Diesel  Individual       Manual   First Owner
# 4  2007     120000  Petrol  Individual       Manual   First Owner
#
#   mileage (kmpl)  engine (cc)   max_power  seats  selling_price
# 0           23.4       1248.0      74 bhp    5.0         450000
# 1          21.14       1498.0  103.52 bhp    5.0         370000
# 2           17.7       1497.0      78 bhp    5.0         158000
# 3             23       1396.0      90 bhp    5.0         225000
# 4           16.1       1298.0    88.2 bhp    5.0         130000

# %% [markdown]
# ## Data Pre-processing

# %%
data['mileage (kmpl)'] = data['mileage (kmpl)'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
data['mileage (kmpl)'].describe()
# Out:
# count    7906.000000
# mean      927.248039
# std       943.448162
# min         0.000000
# 25%       168.000000
# 50%       232.000000
# 75%      1944.000000
# max      3344.000000
# Name: mileage (kmpl), dtype: float64

# %%
data['max_power'] = data['max_power'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
data['max_power'].describe()
# Out:
# count      7906.000000
# mean       2766.125348
# std        5162.123778
# min          35.000000
# 25%         100.000000
# 50%         739.000000
# 75%        3748.000000
# max      108495.000000
# Name: max_power, dtype: float64

# %%
data = data.dropna(axis = 0)
data.describe(include = 'all')
# Out:
#                year     km_driven    fuel seller_type transmission  \
# count   7906.000000  7.906000e+03    7906        7906         7906
# unique          NaN           NaN       4           3            2
# top             NaN           NaN  Diesel  Individual       Manual
# freq            NaN           NaN    4299        6563         6865
# mean    2013.983936  6.918866e+04     NaN         NaN          NaN
# std        3.863695  5.679230e+04     NaN         NaN          NaN
# min     1994.000000  1.000000e+00     NaN         NaN          NaN
# 25%     2012.000000  3.500000e+04     NaN         NaN          NaN
# 50%     2015.000000  6.000000e+04     NaN         NaN          NaN
# 75%     2017.000000  9.542500e+04     NaN         NaN          NaN
# max     2020.000000  2.360457e+06     NaN         NaN          NaN
#
#               owner  mileage (kmpl)  engine (cc)      max_power        seats  \
# count          7906     7906.000000  7906.000000    7906.000000  7906.000000
# unique            5             NaN          NaN            NaN          NaN
# top     First Owner             NaN          NaN            NaN          NaN
# freq           5215             NaN          NaN            NaN          NaN
# mean            NaN      927.248039  1458.708829    2766.125348     5.416393
# std             NaN      943.448162   503.893057    5162.123778     0.959208
# min             NaN        0.000000   624.000000      35.000000     2.000000
# 25%             NaN      168.000000  1197.000000     100.000000     5.000000
# 50%             NaN      232.000000  1248.000000     739.000000     5.000000
# 75%             NaN     1944.000000  1582.000000    3748.000000     5.000000
# max             NaN     3344.000000  3604.000000  108495.000000    14.000000
#
#         selling_price
# count    7.906000e+03
# unique            NaN
# top               NaN
# freq              NaN
# mean     6.498137e+05
# std      8.135827e+05
# min      2.999900e+04
# 25%      2.700000e+05
# 50%      4.500000e+05
# 75%      6.900000e+05
# max      1.000000e+07

# %% [markdown]
# ## Applyting ML algorithm

# %%
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

CT = ColumnTransformer(transformers = [('encoder', OneHotEncoder(), [2,3,4,5])], remainder = 'passthrough')
X_train = CT.fit_transform(X_train)
X_test = CT.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler

SS = StandardScaler()
X_train = SS.fit_transform(X_train)
X_test = SS.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

LR = LinearRegression()
LR.fit(X_train,y_train)
y_pred = LR.predict(X_test)
print("r2 Score: ", r2_score(y_test,y_pred))
# Out:
# r2 Score:  0.6030049953368724

# %%
from sklearn.tree import DecisionTreeRegressor

DC = DecisionTreeRegressor()
DC.fit(X_train,y_train)
y_pred = DC.predict(X_test)
print("r2 Score: ", r2_score(y_test,y_pred))
# Out:
# r2 Score:  0.9143834055112482

# %%
from sklearn.ensemble import RandomForestRegressor

RF = RandomForestRegressor()
RF.fit(X_train,y_train)
y_pred = RF.predict(X_test)
print("r2 Score: ", r2_score(y_test,y_pred))
# Out:
# r2 Score:  0.9487158067782328
